# %%
import pandas as pd
import requests
import json

# %%
api_route_raw = open('API_SETTINGS.json')
api_route = json.loads(api_route_raw.read())

# %%
api_route
# Out:
# {'API_BASE_ROUTE': 'http://localhost:8210/TwitReactionLog/'}

# %%
twitstats_base=api_route['API_BASE_ROUTE']

# %%
data = requests.get(twitstats_base+'posts/user/NyanNyanners/30')\
                         .json()
df = pd.DataFrame.from_dict(data)

# %%
df.head()
# Out:
#        userName  retweets  favorites  followers hashtags  media  \
# 0  NyanNyanners        13       1121     329933            text
# 1  NyanNyanners       657       9005     329933           image
# 2  NyanNyanners        48       1191     329933            text
# 3  NyanNyanners        69       1666     329933            text
# 4  NyanNyanners         2        137     329933            text
#
#                              date  \
# 0  Fri Oct 22 23:36:16 +0000 2021
# 1  Fri Oct 22 23:35:40 +0000 2021
# 2  Thu Oct 21 22:11:17 +0000 2021
# 3  Thu Oct 21 20:33:43 +0000 2021
# 4  Thu Oct 21 20:22:48 +0000 2021
#
#                                                 text
# 0  thank you @/KaptivateTV for the really cute va...
# 1  Happy Spooky Birthday @LichVtuber 💀 !\nI hope ...
# 2  DID YOU SEE IT? 👉⭕️ \nthere are some downright...
# 3  I will be on Mousey's stream tonight at 8pm ET...
# 4      @Nia_0703 I went to doctor school I promise 🥺

# %%
df.loc[df['media'] == "image"]
# Out:
#         userName  retweets  favorites  followers hashtags  media  \
# 1   NyanNyanners       657       9005     329933           image
# 7   NyanNyanners        70       2119     329933           image
# 17  NyanNyanners       494       8091     329933           image
# 29  NyanNyanners       103       2196     329933           image
# 37  NyanNyanners       450       9232     329933           image
# 41  NyanNyanners       471       9256     329933           image
# 45  NyanNyanners       562       9296     329933           image
# 55  NyanNyanners       699       9152     329933           image
# 67  NyanNyanners       225       8053     329933           image
# 70  NyanNyanners       124       2662     329933           image
# 71  NyanNyanners       318       6414     329933           image
#
#                               date  \
# 1   Fri Oct 22 23:35:40 +0000 2021
# 7   Tue Oct 19 20:43:51 +0000 2021
# 17  Wed Oct 13 00:33:46 +0000 2021
# 29  Mon Oct 11 15:00:00 +0000 2021
# 37  Fri Oct 08 20:58:30 +0000 2021
# 41  Thu Oct 07 17:52:47 +0000 2021
# 45  Thu Oct 07 00:39:55 +0000 2021
# 55  Sat Oct 02 00:21:51 +0000 2021
# 67  Tue Sep 28 04:18:50 +0000 2021
# 70  Mon Sep 27 17:43:14 +0000 2021
# 71  Sun Sep 26 19:23:41 +0000 2021
#
#                                                  text
# 1   Happy Spooky Birthday @LichVtuber 💀 !\nI hope ...
# 7   https://t.co/ZAcGQhOrZN\n👻live👻\n\nim going to...
# 17     im idiot sandwitch ;_; https://t.co/N2OwlsL2bp
# 29  💜👻 THIS WEEK'S SCHEDULE 👻💜\nLots of fun collab...
# 37                    ehheheh https://t.co/dat8J9LsnM
# 41  i hate my search history so much https://t.co/...
# 45   here is my dating resume https://t.co/lFyR9DNNyM
# 55  give me ur souls or blood echoes and I'll leve...
# 67     THANK YOU FOR WATCHING https://t.co/EpgtKwcNCz
# 70  schedule for this week  💜\nwith a new design b...
# 71  TOMORROW\nit's spooky time 👻 https://t.co/DUtY...

# %%
df.loc[df['media'] == "text"]
# Out:
#         userName  retweets  favorites  followers       hashtags media  \
# 0   NyanNyanners        13       1121     329933                 text
# 2   NyanNyanners        48       1191     329933                 text
# 3   NyanNyanners        69       1666     329933                 text
# 4   NyanNyanners         2        137     329933                 text
# 6   NyanNyanners        46       3379     329933                 text
# ..           ...       ...        ...        ...            ...   ...
# 76  NyanNyanners         0         48     329933                 text
# 77  NyanNyanners         6        580     329933                 text
# 78  NyanNyanners        73       1655     329933  KizunaAI_VFC   text
# 79  NyanNyanners        41       2977     329933                 text
# 80  NyanNyanners       112       6688     329933                 text
#
#                               date  \
# 0   Fri Oct 22 23:36:16 +0000 2021
# 2   Thu Oct 21 22:11:17 +0000 2021
# 3   Thu Oct 21 20:33:43 +0000 2021
# 4   Thu Oct 21 20:22:48 +0000 2021
# 6   Wed Oct 20 19:32:38 +0000 2021
# ..                             ...
# 76  Sat Sep 25 18:39:58 +0000 2021
# 77  Sat Sep 25 17:31:05 +0000 2021
# 78  Fri Sep 24 23:26:59 +0000 2021
# 79  Fri Sep 24 23:08:49 +0000 2021
# 80  Fri Sep 24 07:07:44 +0000 2021
#
#                                                  text
# 0   thank you @/KaptivateTV for the really cute va...
# 2   DID YOU SEE IT? 👉⭕️ \nthere are some downright...
# 3   I will be on Mousey's stream tonight at 8pm ET...
# 4       @Nia_0703 I went to doctor school I promise 🥺
# 6   aahhhh man the one time this week I'm good and...
# ..                                                ...
# 76  @ConnorTallz @no1shyv @skeb_jp was it really n...
# 77  @haruka_karibu new cute caribou noises unlocked 😳
# 78  ⏰8PM PT Today!\n\nI'm gonna watch the Kizuna A...
# 79                            @takanashikiara I agree
# 80   next week...i will defeat sin\ni must defeat sin
#
# [63 rows x 8 columns]

# %%
df.loc[(df['media'] == "text") & (df['favorites'] >= 1000)]
# Out:
#         userName  retweets  favorites  followers       hashtags media  \
# 0   NyanNyanners        13       1121     329933                 text
# 2   NyanNyanners        48       1191     329933                 text
# 3   NyanNyanners        69       1666     329933                 text
# 6   NyanNyanners        46       3379     329933                 text
# 8   NyanNyanners        11       2008     329933                 text
# 9   NyanNyanners       209       5613     329933                 text
# 11  NyanNyanners        92       2274     329933                 text
# 12  NyanNyanners        69       5269     329933                 text
# 14  NyanNyanners        63       1302     329933                 text
# 15  NyanNyanners        93       3175     329933                 text
# 18  NyanNyanners        13       1105     329933                 text
# 20  NyanNyanners        46       3027     329933                 text
# 21  NyanNyanners        80       1490     329933                 text
# 22  NyanNyanners        18       2225     329933                 text
# 24  NyanNyanners        17       2442     329933                 text
# 25  NyanNyanners       249      10528     329933                 text
# 28  NyanNyanners        74       5339     329933                 text
# 30  NyanNyanners        76       2510     329933                 text
# 33  NyanNyanners        99       1748     329933                 text
# 35  NyanNyanners       153       2365     329933                 text
# 36  NyanNyanners        24       3163     329933                 text
# 38  NyanNyanners        50       4116     329933                 text
# 39  NyanNyanners        55       1387     329933                 text
# 43  NyanNyanners        76       4214     329933                 text
# 44  NyanNyanners       478      10996     329933                 text
# 46  NyanNyanners        71       1521     329933                 text
# 47  NyanNyanners        45       1716     329933                 text
# 49  NyanNyanners       265       5427     329933                 text
# 50  NyanNyanners        96       2075     329933                 text
# 52  NyanNyanners        14       1585     329933                 text
# 54  NyanNyanners       160       6541     329933                 text
# 56  NyanNyanners        21       1159     329933                 text
# 57  NyanNyanners        12       1049     329933                 text
# 58  NyanNyanners        70       3885     329933                 text
# 59  NyanNyanners       186       8872     329933                 text
# 60  NyanNyanners        31       1727     329933                 text
# 61  NyanNyanners        30       3063     329933                 text
# 62  NyanNyanners       658      10079     329933                 text
# 65  NyanNyanners       405       8760     329933                 text
# 68  NyanNyanners       134       2386     329933                 text
# 74  NyanNyanners       271       6631     329933                 text
# 78  NyanNyanners        73       1655     329933  KizunaAI_VFC   text
# 79  NyanNyanners        41       2977     329933                 text
# 80  NyanNyanners       112       6688     329933                 text
#
#                               date  \
# 0   Fri Oct 22 23:36:16 +0000 2021
# 2   Thu Oct 21 22:11:17 +0000 2021
# 3   Thu Oct 21 20:33:43 +0000 2021
# 6   Wed Oct 20 19:32:38 +0000 2021
# 8   Tue Oct 19 18:51:35 +0000 2021
# 9   Tue Oct 19 18:47:49 +0000 2021
# 11  Mon Oct 18 19:15:12 +0000 2021
# 12  Thu Oct 14 01:12:44 +0000 2021
# 14  Wed Oct 13 20:39:51 +0000 2021
# 15  Wed Oct 13 19:02:00 +0000 2021
# 18  Tue Oct 12 23:54:39 +0000 2021
# 20  Tue Oct 12 18:07:00 +0000 2021
# 21  Mon Oct 11 23:34:18 +0000 2021
# 22  Mon Oct 11 20:58:36 +0000 2021
# 24  Mon Oct 11 19:28:54 +0000 2021
# 25  Mon Oct 11 19:25:31 +0000 2021
# 28  Mon Oct 11 17:50:54 +0000 2021
# 30  Mon Oct 11 00:13:18 +0000 2021
# 33  Sat Oct 09 23:12:54 +0000 2021
# 35  Sat Oct 09 01:02:09 +0000 2021
# 36  Fri Oct 08 22:08:17 +0000 2021
# 38  Fri Oct 08 01:44:58 +0000 2021
# 39  Thu Oct 07 20:52:07 +0000 2021
# 43  Thu Oct 07 03:01:12 +0000 2021
# 44  Thu Oct 07 00:55:31 +0000 2021
# 46  Wed Oct 06 20:49:50 +0000 2021
# 47  Tue Oct 05 21:55:45 +0000 2021
# 49  Mon Oct 04 20:13:53 +0000 2021
# 50  Mon Oct 04 19:52:17 +0000 2021
# 52  Mon Oct 04 01:21:06 +0000 2021
# 54  Sat Oct 02 19:53:05 +0000 2021
# 56  Fri Oct 01 21:27:14 +0000 2021
# 57  Fri Oct 01 21:22:45 +0000 2021
# 58  Fri Oct 01 21:13:02 +0000 2021
# 59  Fri Oct 01 19:52:14 +0000 2021
# 60  Thu Sep 30 20:51:47 +0000 2021
# 61  Thu Sep 30 19:31:02 +0000 2021
# 62  Thu Sep 30 02:55:57 +0000 2021
# 65  Wed Sep 29 00:53:26 +0000 2021
# 68  Mon Sep 27 23:12:22 +0000 2021
# 74  Sat Sep 25 22:44:00 +0000 2021
# 78  Fri Sep 24 23:26:59 +0000 2021
# 79  Fri Sep 24 23:08:49 +0000 2021
# 80  Fri Sep 24 07:07:44 +0000 2021
#
#                                                  text
# 0   thank you @/KaptivateTV for the really cute va...
# 2   DID YOU SEE IT? 👉⭕️ \nthere are some downright...
# 3   I will be on Mousey's stream tonight at 8pm ET...
# 6   aahhhh man the one time this week I'm good and...
# 8   i goofed and overslept due to too much hardcor...
# 9                            eat\nsleep\nmine\nrepeat
# 11  schedule for oct. 18th💜\nthis week is kinda bu...
# 12  i love playing minecraft with my friends oooou...
# 14  https://t.co/ZAcGQhOrZN\n👻LIVE👻\n\nMousey, Snu...
# 15  Today's collab stream is gonna have to be push...
# 18              @kureijiollie HAPPY BIRTHDAY OLLIEEEE
# 20  Aaaaaah I woke up late...I mined and crafted t...
# 21  https://t.co/ZAcGQhOrZN\n👻 LIVE 👻\n\ndoin a Mi...
# 22               @ironmouse Lets flail together gamer
# 24  ok I will get a treadmill to get rid of my ene...
# 25  do u ever get a burst of excitement and just r...
# 28  I need to watch squid game but i'm worried tha...
# 30  thank you for a very sweet stream yesterday 😄\...
# 33  👻🍪LIVE🍪👻\nhttps://t.co/ZAcGQhOrZN\n\nChecking ...
# 35  👻🍪TOMORROW'S STREAM 🍪👻\n⏰10/9 4PM PT / 7PM ET\...
# 36           @ironmouse im so ready to mine and craft
# 38                                        i had fun 👴
# 39  https://t.co/ZAcGQhOrZN\n👻 LIVE 👻\n\nyesterday...
# 43                               i laughed and i lost
# 44  I'm a cute pink cat and I slimed my undergarme...
# 46  https://t.co/ZAcGQhOrZN\n👻 LIVE 👻\n\ntwitch is...
# 47  @VShojoOfficial @pineapplelava @Merryweatherey...
# 49  i want to play Elden Ring i want to play Elden...
# 50  👻 This Week's Schedule 👻\n\nIt's kind of a wei...
# 52        @zentreya hi!!! It's good to see you back!!
# 54  my cat sounds like a geiger counter when he purrs
# 56  I binged season 4 of documental last night so ...
# 57  @snuffyowo it's like if u lose u get punished ...
# 58  there needs to be a no laughing batsu challeng...
# 59  not gonna lie i feel really down and this mont...
# 60  @_Silvervale_ mommy mommy momy  momyo momy mom...
# 61  internet connection is not cooperating with me...
# 62  forgot to post it after I debuted it on monday...
# 65                               video games are good
# 68  https://t.co/ZAcGQhOrZN\n👻 LIVE 👻\n\nrevealing...
# 74                   I can smell Halloween in the air
# 78  ⏰8PM PT Today!\n\nI'm gonna watch the Kizuna A...
# 79                            @takanashikiara I agree
# 80   next week...i will defeat sin\ni must defeat sin

# %%
data_set2 = requests.get(twitstats_base+'posts/user/elonmusk/30')\
                         .json()

# %%
combined_set=pd.concat([df,pd.DataFrame.from_dict(data_set2)])

# %%
combined_set.loc[(combined_set['media'] == "text") & (combined_set['favorites'] >= 10000)]
# Out:
#          userName  retweets  favorites  followers hashtags media  \
# 25   NyanNyanners       249      10528     329933           text
# 44   NyanNyanners       478      10996     329933           text
# 62   NyanNyanners       658      10079     329933           text
# 0        elonmusk      3513      31086   61253419           text
# 2        elonmusk       554      11114   61253419           text
# ..            ...       ...        ...        ...      ...   ...
# 181      elonmusk       436      16072   61253419           text
# 182      elonmusk      1012      10185   61253419           text
# 186      elonmusk      1021      13517   61253419           text
# 189      elonmusk       796      18555   61253419           text
# 191      elonmusk      1121      21904   61253419           text
#
#                                date  \
# 25   Mon Oct 11 19:25:31 +0000 2021
# 44   Thu Oct 07 00:55:31 +0000 2021
# 62   Thu Sep 30 02:55:57 +0000 2021
# 0    Sat Oct 23 14:50:00 +0000 2021
# 2    Sat Oct 23 13:43:53 +0000 2021
# ..                              ...
# 181  Wed Sep 29 22:20:42 +0000 2021
# 182  Wed Sep 29 19:53:08 +0000 2021
# 186  Tue Sep 28 17:36:43 +0000 2021
# 189  Tue Sep 28 05:01:14 +0000 2021
# 191  Tue Sep 28 04:23:38 +0000 2021
#
#                                                   text
# 25   do u ever get a burst of excitement and just r...
# 44   I'm a cute pink cat and I slimed my undergarme...
# 62   forgot to post it after I debuted it on monday...
# 0    Your support makes a big difference! Please le...
# 2    Regression in some left turns at traffic light...
# ..                                                 ...
# 181                             @SciGuySpace @verge 🤣🤣
# 182  @thesheetztweetz SpaceX has sued to be *allowe...
# 186                 @BillyM2k Hamster has mad skillz!!
# 189  Apologies, 10.2 release will be a week from Fr...
# 191  Wow, lot of interest in FSD beta! Plan is to r...
#
# [76 rows x 8 columns]

# %%
df_local_file1 = pd.read_json("jiyuna_10212021_last30d.json")

# %%
df_local_file1  = df_local_file1.drop(['text'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-cb31d4e5d715> in <module>
# ----> 1 df_local_file1  =df_local_file1.drop(['text'], axis=1)
#       2 df_reduced = df_local_file1.loc[(df_local_file1['favorites'] >= 1000)]
#       3 df_reduced.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['text'] not found in axis"

# %%
df_reduced = df_local_file1.loc[(df_local_file1['favorites'] >= 1000)]
combined_set=pd.concat([combined_set, df_reduced])

# %%
hashtags_set=combined_set[~combined_set['hashtags'].isnull() & combined_set['hashtags'].str.len() > 0]

# %%
hashtags_set.to_csv('twitter_resutls_with_hashtag_10212021.csv')

# %%
parsed = json.loads(hashtags_set.drop(['text'], axis=1).to_json(orient="records"))

with open('data.json', 'w') as outfile:
     json.dump(parsed , outfile, sort_keys = True, indent = 4,
               ensure_ascii = False)
